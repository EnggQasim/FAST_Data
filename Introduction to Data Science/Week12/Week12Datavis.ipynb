# %%
#Importing the Dataset. in this case Iris.data
import matplotlib.pyplot as plt
import pandas as pd
iris = pd.read_csv('iris.data', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# 1. Data Visualization using Matplotlib ---Scatter Plots---
# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(iris['sepal_length'], iris['sepal_width'])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
# create color dictionary
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i],color=colors[iris['class'][i]])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
# 1. Data Visualization using Matplotlib ---Line Chart---
# get columns to plot
columns = iris.columns.drop(['class'])
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, iris[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
# 1. Data Visualization using Matplotlib ---Histogram---
# create figure and axis
fig, ax = plt.subplots()
# plot histogram
ax.hist(iris['sepal_length'])
# set title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('Length')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = iris['sepal_length'].value_counts() 
# get x and y data 
points = data.index 
frequency = data.values 
# create bar chart 
ax.bar(points, frequency) 
# set title and labels 
ax.set_title('Iris Dataset') 
ax.set_xlabel('Length') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# 2 Pandas Visualizations of the Iris dataset ---Scatter Plot---
iris.plot.scatter(x='sepal_length', y='sepal_width', title='Iris Dataset')

# %%
# 2 Pandas Visualizations of the Iris dataset ---Line Chart---
iris.drop(['class'], axis=1).plot.line(title='Iris Dataset')

# %%
# 2 Pandas Visualizations of the Iris dataset ---Histogram---
iris['sepal_length'].plot.hist()

# %%
iris.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F70B9A7240>,
# ...
#       dtype=object)

# %%
# 2 Pandas Visualizations of the Iris dataset ---Bar Charts---
iris['sepal_length'].value_counts().sort_index().plot.bar()

# %%
iris['sepal_length'].value_counts().sort_index().plot.barh()

# %%
iris.groupby("class").sepal_length.mean().sort_values(ascending=False)[:5].plot.bar()

# %%
# Data Visualization through Seaborn --Scatter plot--
import seaborn as sns
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='class', data=iris)

# %%
# Data Visualization through Seaborn --Line plot--
sns.lineplot(data=iris.drop(['class'], axis=1))

# %%
sns.distplot(iris['sepal_length'], bins=10, kde=False)

# %%
# Histogram with gaussian kernel density estimate
sns.distplot(iris['sepal_length'], bins=10, kde=True)

# %%
# Data Visualization through Seaborn --Bar chart
sns.countplot(iris['sepal_length'])

# %%
# Data Visualization through Seaborn --Box plots--
df = iris[(iris['sepal_length']>=4.5) & (iris['petal_length']>1.5)]
sns.boxplot('sepal_length', 'petal_length', data=df)
