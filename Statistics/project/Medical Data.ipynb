# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("./medical/Medical Data for MS Course Project (Research).xlsx")
df.columns = ['sno','Age','Gender','DIAGNOSIS','YEAR']
df.dtypes
# Out:
# sno           int64
# Age           int64
# Gender       object
# DIAGNOSIS    object
# YEAR          int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# sno          0
# Age          0
# Gender       0
# DIAGNOSIS    0
# YEAR         0
# dtype: int64

# %%
for column in df.columns:
    print(column, ":",len(df[column].unique()))
# Out:
# sno : 6907
# Age : 56
# Gender : 2
# DIAGNOSIS : 20
# YEAR : 5

# %% [markdown]
# # Age vs Disease

# %%
df.Age.hist()

# %%
fig, ax = plt.subplots(nrows=2,ncols=10)

for cell,digno in enumerate(df.DIAGNOSIS.unique()):
    ax[cell]=df[df.DIAGNOSIS==digno].Age.hist()
    
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-45044c052001> in <module>
#       2
#       3 for cell,digno in enumerate(df.DIAGNOSIS.unique()):
# ----> 4     ax[cell]=df[df.DIAGNOSIS==digno].Age.hist()
#       5
#       6 plt.plot()
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
df.groupby(by='Age').agg(['count'])[['DIAGNOSIS']].plot(kind='bar',figsize=(10,6))

# %%
df.groupby(by=['DIAGNOSIS','Age']).hist()
plt.legend()
# Out:
# /home/muhammadqasim/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# No handles with labels found to put in legend.
